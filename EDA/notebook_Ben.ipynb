# %%
import numpy as np
import pandas as pd

# %% [markdown]
# A chaque fois, dans chaque dataset, on a les données en somme cumulée (sum), en moyenne (average) et en écart-type (std).

# %% [markdown]
# A priori on a les données sur toute une saison.

# %% [markdown]
# ### Datasets Team

# %%
df_train_home_team = pd.read_csv('../DATA/input/raw/train/train_home_team_statistics_df.csv')
df_train_away_team = pd.read_csv('../DATA/input/raw/train/train_away_team_statistics_df.csv')

# %%
df_train_home_team.head()
# Out:
#    ID          LEAGUE                TEAM_NAME  TEAM_SHOTS_TOTAL_season_sum  \
# 0   0         Ligue 1                 Toulouse                          3.0
# 1   1         Ligue 2                    Brest                          6.0
# 2   2         Serie A                Sampdoria                          4.0
# 3   3      League One            Coventry City                          7.0
# 4   4  Premier League  Wolverhampton Wanderers                          3.0
#
#    TEAM_SHOTS_INSIDEBOX_season_sum  TEAM_SHOTS_OFF_TARGET_season_sum  \
# 0                              2.0                               5.0
# 1                              8.0                               3.0
# 2                              2.0                               5.0
# 3                              5.0                               5.0
# 4                              3.0                               2.0
#
#    TEAM_SHOTS_ON_TARGET_season_sum  TEAM_SHOTS_OUTSIDEBOX_season_sum  \
# ...

# %%
df_train_home_team.shape
# Out:
# (12303, 143)

# %%
df_train_home_team.columns
# Out:
# Index(['ID', 'LEAGUE', 'TEAM_NAME', 'TEAM_SHOTS_TOTAL_season_sum',
#        'TEAM_SHOTS_INSIDEBOX_season_sum', 'TEAM_SHOTS_OFF_TARGET_season_sum',
#        'TEAM_SHOTS_ON_TARGET_season_sum', 'TEAM_SHOTS_OUTSIDEBOX_season_sum',
#        'TEAM_PASSES_season_sum', 'TEAM_SUCCESSFUL_PASSES_season_sum',
#        ...
#        'TEAM_YELLOWCARDS_5_last_match_std', 'TEAM_REDCARDS_5_last_match_std',
#        'TEAM_OFFSIDES_5_last_match_std', 'TEAM_ATTACKS_5_last_match_std',
#        'TEAM_PENALTIES_5_last_match_std',
#        'TEAM_SUBSTITUTIONS_5_last_match_std',
#        'TEAM_BALL_SAFE_5_last_match_std',
#        'TEAM_DANGEROUS_ATTACKS_5_last_match_std',
#        'TEAM_INJURIES_5_last_match_std', 'TEAM_GOALS_5_last_match_std'],
#       dtype='object', length=143)

# %%
df_train_away_team.head()
# Out:
#    ID          LEAGUE            TEAM_NAME  TEAM_SHOTS_TOTAL_season_sum  \
# 0   0         Ligue 1  Olympique Marseille                          4.0
# 1   1         Ligue 2             Red Star                          4.0
# 2   2         Serie A              Bologna                          4.0
# 3   3      League One     Bolton Wanderers                          0.0
# 4   4  Premier League       Leicester City                          5.0
#
#    TEAM_SHOTS_INSIDEBOX_season_sum  TEAM_SHOTS_OFF_TARGET_season_sum  \
# 0                              1.0                               4.0
# 1                              3.0                               4.0
# 2                              3.0                               4.0
# 3                              0.0                               0.0
# 4                              4.0                               5.0
#
#    TEAM_SHOTS_ON_TARGET_season_sum  TEAM_SHOTS_OUTSIDEBOX_season_sum  \
# ...

# %%
df_train_away_team.shape
# Out:
# (12303, 143)

# %%
df_train_away_team.columns == df_train_home_team.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %% [markdown]
# Ok donc c'est les même datasets, chaque ID correspond à un match, dans la table home on a les données de l'équipe à domicile et dans la table away on a les données de l'équipe qui joue à l'extérieur.

# %% [markdown]
# ### Datasets Players

# %%
df_train_home_player = pd.read_csv('../DATA/input/raw/train/train_home_player_statistics_df.csv')
df_train_away_player = pd.read_csv('../DATA/input/raw/train/train_away_player_statistics_df.csv')

# %%
df_train_home_player.head()
# Out:
#    ID   LEAGUE TEAM_NAME    POSITION          PLAYER_NAME  \
# 0   0  Ligue 1  Toulouse    defender        Agustín Rogel
# 1   0  Ligue 1  Toulouse    defender    Mathieu Goncalves
# 2   0  Ligue 1  Toulouse  goalkeeper      Baptiste Reynet
# 3   0  Ligue 1  Toulouse  midfielder  Jean-Victor Makengo
# 4   0  Ligue 1  Toulouse         NaN  Efthymios Koulouris
#
#    PLAYER_ACCURATE_CROSSES_season_sum  PLAYER_ACCURATE_PASSES_season_sum  \
# 0                                 0.0                                8.0
# 1                                 0.0                                7.0
# 2                                 0.0                               33.0
# 3                                 8.0                               27.0
# 4                                 2.0                               23.0
#
#    PLAYER_AERIALS_WON_season_sum  PLAYER_ASSISTS_season_sum  \
# 0                            5.0                        0.0
# ...

# %%
df_train_home_player.shape
# Out:
# (237079, 307)

# %%
df_train_home_player.shape[0] / df_train_home_team.shape[0]
# Out:
# 19.27001544338779

# %% [markdown]
# Donc ça ça veut dire qu'on compte en moyenne 19,3 joueurs par équipe (à domicile) par match, donc on parle bien de la feuille de match.

# %%
df_train_home_player.columns
# Out:
# Index(['ID', 'LEAGUE', 'TEAM_NAME', 'POSITION', 'PLAYER_NAME',
#        'PLAYER_ACCURATE_CROSSES_season_sum',
#        'PLAYER_ACCURATE_PASSES_season_sum', 'PLAYER_AERIALS_WON_season_sum',
#        'PLAYER_ASSISTS_season_sum', 'PLAYER_BIG_CHANCES_CREATED_season_sum',
#        ...
#        'PLAYER_STARTING_LINEUP_5_last_match_std',
#        'PLAYER_SUCCESSFUL_DRIBBLES_5_last_match_std',
#        'PLAYER_TACKLES_5_last_match_std',
#        'PLAYER_TOTAL_CROSSES_5_last_match_std',
#        'PLAYER_TOTAL_DUELS_5_last_match_std',
#        'PLAYER_YELLOWCARDS_5_last_match_std',
#        'PLAYER_PUNCHES_5_last_match_std', 'PLAYER_LONG_BALLS_5_last_match_std',
#        'PLAYER_LONG_BALLS_WON_5_last_match_std',
#        'PLAYER_SHOTS_OFF_TARGET_5_last_match_std'],
#       dtype='object', length=307)

# %%
df_train_away_player.head()
# Out:
#    ID   LEAGUE            TEAM_NAME    POSITION           PLAYER_NAME  \
# 0   0  Ligue 1  Olympique Marseille    defender          Lucas Perrin
# 1   0  Ligue 1  Olympique Marseille  midfielder       Kevin Strootman
# 2   0  Ligue 1  Olympique Marseille  goalkeeper           Yohann Pelé
# 3   0  Ligue 1  Olympique Marseille    defender  Abdallah Ali Mohamed
# 4   0  Ligue 1  Olympique Marseille         NaN      Nemanja Radonjic
#
#    PLAYER_ACCURATE_CROSSES_season_sum  PLAYER_ACCURATE_PASSES_season_sum  \
# 0                                 0.0                               19.0
# 1                                 2.0                               48.0
# 2                                 0.0                                0.0
# 3                                 0.0                                0.0
# 4                                 8.0                               11.0
#
#    PLAYER_AERIALS_WON_season_sum  PLAYER_ASSISTS_season_sum  \
# ...

# %% [markdown]
# Ok donc c'est bien le même ID de match, avec certainement tous les joueurs qu'il y a sur la feuille de match et leurs stats avant le match.

# %% [markdown]
# ### Voyons si les données des joueurs changent au cours de la saison

# %%
mask = df_train_home_player["PLAYER_NAME"] == "Lucas Perrin"

df_train_home_player[mask].head()
# Out:
#         ID   LEAGUE            TEAM_NAME  POSITION   PLAYER_NAME  \
# 1809    93  Ligue 1  Olympique Marseille  defender  Lucas Perrin
# 8500   438  Ligue 1  Olympique Marseille  defender  Lucas Perrin
# 13029  673  Ligue 1  Olympique Marseille  defender  Lucas Perrin
# 15589  806  Ligue 1  Olympique Marseille  defender  Lucas Perrin
# 17766  918  Ligue 1  Olympique Marseille  defender  Lucas Perrin
#
#        PLAYER_ACCURATE_CROSSES_season_sum  PLAYER_ACCURATE_PASSES_season_sum  \
# 1809                                  0.0                                0.0
# 8500                                  0.0                               24.0
# 13029                                 0.0                               18.0
# 15589                                 0.0                               22.0
# 17766                                 0.0                               16.0
#
#        PLAYER_AERIALS_WON_season_sum  PLAYER_ASSISTS_season_sum  \
# ...

# %%
df_train_home_player[mask].shape
# Out:
# (19, 307)

# %% [markdown]
# Donc ça correspond bien aux 19 matchs de l'OM joués en une saison, donc on devrait pouvoir être capable de les classer.

# %%
# Voir combien on a de joueurs différents de l'OM

mask = df_train_home_player["TEAM_NAME"] == "Olympique Marseille"

df_train_home_player[mask]['PLAYER_NAME'].nunique()
# Out:
# 52

# %%
df_train_home_player[mask]['PLAYER_NAME'].unique()
# Out:
# array(['Hiroki Sakai', 'Saîf-Eddine Khaoui', 'Florian Thauvin',
#        'Valère Germain', 'Steve Mandanda', 'Lucas Perrin',
#        'Yuto Nagatomo', 'Luis Henrique', 'Michaël Cuisance',
#        'Cheick Souare', 'Dimitri Payet', 'Yohann Pelé',
#        'Nemanja Radonjic', 'Marley Aké', 'Pape Gueye\xa0',
#        'Leonardo Balerdi', 'Valentin Rongier', 'Morgan Sanson',
#        'Darío Benedetto', 'Duje Caleta-Car', 'Niels Nkounkou',
#        'Kevin Strootman', 'Bouna Sarr', 'Jordan Amavi', 'Maxime López',
#        'Boubacar Kamara', 'Alexandre Philiponeau', 'Florian Chabrolle',
#        'Abdallah Ali Mohamed', 'Álvaro González', 'Fabio Vanni',
#        'A. Dieng', 'Luiz Gustavo', 'Mario Balotelli', "Clinton N'Jie",
#        'Lucas Ocampos', 'Adil Rami', 'Konstantinos Mitroglou',
#        'Tomáš Hubočan', 'Christopher Rocchia', 'Akio Kogiku',
#        'Grégory Sertic', 'Arkadiusz Milik', 'Pol Lirola',
#        'Olivier Ntcham', 'Isaac Lihadji', 'Florian Escales',
# ...

# %% [markdown]
# Là ça fait beaucoup de joueurs, donc ça m'étonnerait qu'ils aient tous de la data pour tous les matchs

# %%
#Vérifions pour Akio Kogiku, qui me semble n'est pas très connu

mask = df_train_home_player["PLAYER_NAME"] == "Akio Kogiku"

df_train_home_player[mask]
# Out:
#            ID         LEAGUE            TEAM_NAME  POSITION  PLAYER_NAME  \
# 14073     727  Liga Portugal       Sporting Braga  defender  Akio Kogiku
# 26173    1357  Liga Portugal       Sporting Braga  defender  Akio Kogiku
# 39014    2023        Ligue 1  Olympique Marseille  defender  Akio Kogiku
# 68528    3559        Ligue 1  Olympique Marseille  defender  Akio Kogiku
# 87706    4551        Ligue 1  Olympique Marseille  defender  Akio Kogiku
# 102696   5330        Ligue 1  Olympique Marseille  defender  Akio Kogiku
# 105250   5463        Ligue 1  Olympique Marseille  defender  Akio Kogiku
# 122867   6378  Liga Portugal       Sporting Braga  defender  Akio Kogiku
# 130317   6760  Liga Portugal       Sporting Braga  defender  Akio Kogiku
# 132048   6850  Liga Portugal       Sporting Braga  defender  Akio Kogiku
# 134257   6964  Liga Portugal       Sporting Braga  defender  Akio Kogiku
# 167146   8674        Ligue 1  Olympique Marseille  defender  Akio Kogiku
# ...

# %% [markdown]
# Alors ça c'est très chelou pcq ce mec n'est meme pas joueur et n'a jamais joué à l'OM, donc problème dans la donnée.

# %%
#Vérifions pour Akio Kogiku, qui me semble n'est pas très connu

mask = df_train_home_player["PLAYER_NAME"] == "Abdallah Ali Mohamed"

df_train_home_player[mask]
# Out:
#            ID      LEAGUE            TEAM_NAME  POSITION  \
# 13030     673     Ligue 1  Olympique Marseille  defender
# 55055    2860  Pro League        Zulte-Waregem  defender
# 83150    4317     Ligue 1  Olympique Marseille  defender
# 102683   5330     Ligue 1  Olympique Marseille  defender
# 155231   8053  Pro League        Zulte-Waregem  defender
# 156781   8134  Pro League        Zulte-Waregem  defender
# 230001  11937  Pro League        Zulte-Waregem  defender
# 234527  12170     Ligue 1  Olympique Marseille  defender
#
#                  PLAYER_NAME  PLAYER_ACCURATE_CROSSES_season_sum  \
# 13030   Abdallah Ali Mohamed                                 0.0
# 55055   Abdallah Ali Mohamed                                 0.0
# 83150   Abdallah Ali Mohamed                                 NaN
# 102683  Abdallah Ali Mohamed                                 0.0
# 155231  Abdallah Ali Mohamed                                 NaN
# ...
